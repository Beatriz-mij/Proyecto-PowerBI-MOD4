# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df_chi = pd.read_csv("files/Marine Microplastic Concentrations_south_CHINA.csv",
    sep=";",
    engine="python",
    encoding="utf-8",
    quotechar='"',
    on_bad_lines='warn'  # también puedes usar 'skip' para ignorar líneas malas
)

df_chi.head()
# Out:
#    OBJECTID        Date  Latitude  Longitude         Oceans           Regions  \
# 0      9376  14/02/2015   100.888    998.253  Pacific Ocean  Gulf of Thailand
# 1      9395  04/03/2015    71.221    994.243  Pacific Ocean    Malacca Strait
# 2      9757  14/03/2016    35.438  1.002.277  Pacific Ocean    Malacca Strait
# 3      9784  28/12/2015    17.450  1.104.930  Pacific Ocean   South China Sea
# 4      9785  29/12/2015    18.100  1.103.250  Pacific Ocean   South China Sea
#
#           Location Microplastics Measurement (density)       Unit  \
# 0  South China Sea                            0.004000  pieces/m3
# 1  South China Sea                            0.000000  pieces/m3
# 2  South China Sea                            0.077000  pieces/m3
# 3  South China Sea                            0.000000  pieces/m3
# 4  South China Sea                            0.000000  pieces/m3
#
#   Density Range Concentration Class Sampling Method     Short Reference  \
# 0  0.0005-0.005                 Low     Grab sample  Barrows et al.2018
# 1      0-0.0005            Very Low     Grab sample  Barrows et al.2018
# 2       0.005-1              Medium     Grab sample  Barrows et al.2018
# 3      0-0.0005            Very Low     Grab sample  Barrows et al.2018
# 4      0-0.0005            Very Low     Grab sample  Barrows et al.2018
#
#                                       Long Reference  \
# 0  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 1  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 2  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 3  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 4  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
#
#                                             DOI         Organization  \
# 0  https://doi.org/10.1016/j.envpol.2018.02.062  Adventure Scientist
# 1  https://doi.org/10.1016/j.envpol.2018.02.062  Adventure Scientist
# 2  https://doi.org/10.1016/j.envpol.2018.02.062  Adventure Scientist
# 3  https://doi.org/10.1016/j.envpol.2018.02.062  Adventure Scientist
# 4  https://doi.org/10.1016/j.envpol.2018.02.062  Adventure Scientist
#
#    NCEI Accession Number                                NCEI Accession Link
# 0                 211009  https://www.ncei.noaa.gov/access/metadata/land...
# 1                 211009  https://www.ncei.noaa.gov/access/metadata/land...
# 2                 211009  https://www.ncei.noaa.gov/access/metadata/land...
# 3                 211009  https://www.ncei.noaa.gov/access/metadata/land...
# 4                 211009  https://www.ncei.noaa.gov/access/metadata/land...

# %%
# Función para conocer nulos y duplicados en un informe. Next step--> ETL

def nulos_duplicados(df_chi):
    # Cálculo del porcentaje de nulos
    porcentaje_nulos = df_chi.isna().sum() / df_chi.shape[0] * 100
    
    # Verificación de duplicados
    duplicados = df_chi.duplicated().sum()
    if duplicados == 0:
        mensaje_duplicados = "No hay duplicados"
    else:
        mensaje_duplicados = f"Hay {duplicados} duplicados"
    
    # Creación de un reporte bonito y visual
    reporte = f"""
    ===================== Informe de Datos =====================
    
    Porcentaje de Nulos por Columna:
    ------------------------------------------------------------
    {porcentaje_nulos.to_string()}
    
    ------------------------------------------------------------
    Duplicados:
    ------------------------------------------------------------
    {mensaje_duplicados}
    
    ============================================================
    """
    
    # Imprimir directamente el reporte
    print(reporte)

# Ejemplo de uso
# df_mp = pd.DataFrame(...)

# Llamar directamente a la función
nulos_duplicados(df_chi)
# Out:
#     ===================== Informe de Datos =====================
#
#     Porcentaje de Nulos por Columna:
#     ------------------------------------------------------------
#     OBJECTID                               0.0
# Date                                   0.0
# Latitude                               0.0
# Longitude                              0.0
# Oceans                                 0.0
# Regions                                0.0
# Location                               0.0
# Microplastics Measurement (density)    0.0
# Unit                                   0.0
# Density Range                          0.0
# Concentration Class                    0.0
# Sampling Method                        0.0
# Short Reference                        0.0
# Long Reference                         0.0
# DOI                                    0.0
# Organization                           0.0
# NCEI Accession Number                  0.0
# NCEI Accession Link                    0.0
#
#     ------------------------------------------------------------
#     Duplicados:
#     ------------------------------------------------------------
#     No hay duplicados
#
#     ============================================================

# %%
# Función para transformar el número
def transformar_numero(numero):
    # Verificamos si el número es un float o un string
    if isinstance(numero, str):
        # Eliminar los puntos si es una cadena
        return "{:,.4f}".format(int(numero.replace(".", "")) / 10000)
    elif isinstance(numero, float) or isinstance(numero, int):
        # Si es un número, lo dividimos por 10,000 y lo formateamos
        return "{:,.4f}".format(numero / 10000)

# Aplicar la función a la columna
df_chi['Longitude'] = df_chi['Longitude'].apply(transformar_numero)

# %%
df_chi
# Out:
#      OBJECTID        Date  Latitude Longitude         Oceans  \
# 0        9376  14/02/2015   100.888   99.8253  Pacific Ocean
# 1        9395  04/03/2015    71.221   99.4243  Pacific Ocean
# 2        9757  14/03/2016    35.438  100.2277  Pacific Ocean
# 3        9784  28/12/2015    17.450  110.4930  Pacific Ocean
# 4        9785  29/12/2015    18.100  110.3250  Pacific Ocean
# ..        ...         ...       ...       ...            ...
# 177     21672  11/10/2017   217.495  108.5672  Pacific Ocean
# 178     21673  11/10/2017   217.835  108.5466  Pacific Ocean
# 179     21674  11/10/2017   217.968  108.5517  Pacific Ocean
# 180     21675  11/10/2017   218.168  108.5710  Pacific Ocean
# 181     21676  11/10/2017   218.222  108.5517  Pacific Ocean
#
#               Regions         Location Microplastics Measurement (density)  \
# 0    Gulf of Thailand  South China Sea                            0.004000
# 1      Malacca Strait  South China Sea                            0.000000
# 2      Malacca Strait  South China Sea                            0.077000
# 3     South China Sea  South China Sea                            0.000000
# 4     South China Sea  South China Sea                            0.000000
# ..                ...              ...                                 ...
# 177   South China Sea  South China Sea                       9.533.333.333
# 178   South China Sea  South China Sea                       2.266.666.667
# 179   South China Sea  South China Sea                       1.600.000.000
# 180   South China Sea  South China Sea                       3.400.000.000
# 181   South China Sea  South China Sea                       8.800.000.000
#
#           Unit Density Range Concentration Class          Sampling Method  \
# 0    pieces/m3  0.0005-0.005                 Low              Grab sample
# 1    pieces/m3      0-0.0005            Very Low              Grab sample
# 2    pieces/m3       0.005-1              Medium              Grab sample
# 3    pieces/m3      0-0.0005            Very Low              Grab sample
# 4    pieces/m3      0-0.0005            Very Low              Grab sample
# ..         ...           ...                 ...                      ...
# 177  pieces/m3          >=10           Very High  stainless-steel sampler
# 178  pieces/m3          >=10           Very High  stainless-steel sampler
# 179  pieces/m3          >=10           Very High  stainless-steel sampler
# 180  pieces/m3          >=10           Very High  stainless-steel sampler
# 181  pieces/m3          >=10           Very High  stainless-steel sampler
#
#         Short Reference                                     Long Reference  \
# 0    Barrows et al.2018  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 1    Barrows et al.2018  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 2    Barrows et al.2018  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 3    Barrows et al.2018  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 4    Barrows et al.2018  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# ..                  ...                                                ...
# 177     Zhu et al. 2019  Zhu, J., Q. Zhang, Y. Li, S. Tan, Z. Kang, X. ...
# 178     Zhu et al. 2019  Zhu, J., Q. Zhang, Y. Li, S. Tan, Z. Kang, X. ...
# 179     Zhu et al. 2019  Zhu, J., Q. Zhang, Y. Li, S. Tan, Z. Kang, X. ...
# 180     Zhu et al. 2019  Zhu, J., Q. Zhang, Y. Li, S. Tan, Z. Kang, X. ...
# 181     Zhu et al. 2019  Zhu, J., Q. Zhang, Y. Li, S. Tan, Z. Kang, X. ...
#
#                                                  DOI  \
# 0       https://doi.org/10.1016/j.envpol.2018.02.062
# 1       https://doi.org/10.1016/j.envpol.2018.02.062
# 2       https://doi.org/10.1016/j.envpol.2018.02.062
# 3       https://doi.org/10.1016/j.envpol.2018.02.062
# 4       https://doi.org/10.1016/j.envpol.2018.02.062
# ..                                               ...
# 177  https://doi.org/10.1016/j.scitotenv.2018.12.192
# 178  https://doi.org/10.1016/j.scitotenv.2018.12.192
# 179  https://doi.org/10.1016/j.scitotenv.2018.12.192
# 180  https://doi.org/10.1016/j.scitotenv.2018.12.192
# 181  https://doi.org/10.1016/j.scitotenv.2018.12.192
#
#                      Organization  NCEI Accession Number  \
# 0             Adventure Scientist                 211009
# 1             Adventure Scientist                 211009
# 2             Adventure Scientist                 211009
# 3             Adventure Scientist                 211009
# 4             Adventure Scientist                 211009
# ..                            ...                    ...
# 177  Beibu Gulf University, China                 280675
# 178  Beibu Gulf University, China                 280675
# 179  Beibu Gulf University, China                 280675
# 180  Beibu Gulf University, China                 280675
# 181  Beibu Gulf University, China                 280675
#
#                                    NCEI Accession Link
# 0    https://www.ncei.noaa.gov/access/metadata/land...
# 1    https://www.ncei.noaa.gov/access/metadata/land...
# 2    https://www.ncei.noaa.gov/access/metadata/land...
# 3    https://www.ncei.noaa.gov/access/metadata/land...
# 4    https://www.ncei.noaa.gov/access/metadata/land...
# ..                                                 ...
# 177  https://www.ncei.noaa.gov/access/metadata/land...
# 178  https://www.ncei.noaa.gov/access/metadata/land...
# 179  https://www.ncei.noaa.gov/access/metadata/land...
# 180  https://www.ncei.noaa.gov/access/metadata/land...
# 181  https://www.ncei.noaa.gov/access/metadata/land...
#
# [182 rows x 18 columns]

# %%
# Columna de media de density

# Función para eliminar el símbolo '>= y >'
def eliminar_menor_igual(rango):
    return rango.replace('>=','').replace('>','').strip()

# Aplicamos la función para eliminar '>=' de la columna 'Density Range'
df_chi['Density Range'] = df_chi['Density Range'].apply(eliminar_menor_igual)

# %%
# Función para extraer los valores numéricos y calcular el valor central
def calcular_densidad_central(rango):
    # Si el valor es solo un número
    if '-' not in rango:  # Caso cuando no hay guion, es un solo número
        return float(rango.strip())
    
    # Si el valor es un rango (con '-')
    else:
        # Extraemos los valores del rango y calculamos el promedio
        min_val, max_val = map(float, rango.replace(' ', '').split('-'))  # Convertimos los valores en float
        return (min_val + max_val) / 2  # Calculamos el promedio del rango

# Aplicamos la función a la columna 'Density Range' y creamos la nueva columna 'Density_Center'
df_chi['Density Center'] = df_chi['Density Range'].apply(calcular_densidad_central)

# %%
df_chi
# Out:
#      OBJECTID        Date  Latitude Longitude         Oceans  \
# 0        9376  14/02/2015   100.888   99.8253  Pacific Ocean
# 1        9395  04/03/2015    71.221   99.4243  Pacific Ocean
# 2        9757  14/03/2016    35.438  100.2277  Pacific Ocean
# 3        9784  28/12/2015    17.450  110.4930  Pacific Ocean
# 4        9785  29/12/2015    18.100  110.3250  Pacific Ocean
# ..        ...         ...       ...       ...            ...
# 177     21672  11/10/2017   217.495  108.5672  Pacific Ocean
# 178     21673  11/10/2017   217.835  108.5466  Pacific Ocean
# 179     21674  11/10/2017   217.968  108.5517  Pacific Ocean
# 180     21675  11/10/2017   218.168  108.5710  Pacific Ocean
# 181     21676  11/10/2017   218.222  108.5517  Pacific Ocean
#
#               Regions         Location Microplastics Measurement (density)  \
# 0    Gulf of Thailand  South China Sea                            0.004000
# 1      Malacca Strait  South China Sea                            0.000000
# 2      Malacca Strait  South China Sea                            0.077000
# 3     South China Sea  South China Sea                            0.000000
# 4     South China Sea  South China Sea                            0.000000
# ..                ...              ...                                 ...
# 177   South China Sea  South China Sea                       9.533.333.333
# 178   South China Sea  South China Sea                       2.266.666.667
# 179   South China Sea  South China Sea                       1.600.000.000
# 180   South China Sea  South China Sea                       3.400.000.000
# 181   South China Sea  South China Sea                       8.800.000.000
#
#           Unit Density Range Concentration Class          Sampling Method  \
# 0    pieces/m3  0.0005-0.005                 Low              Grab sample
# 1    pieces/m3      0-0.0005            Very Low              Grab sample
# 2    pieces/m3       0.005-1              Medium              Grab sample
# 3    pieces/m3      0-0.0005            Very Low              Grab sample
# 4    pieces/m3      0-0.0005            Very Low              Grab sample
# ..         ...           ...                 ...                      ...
# 177  pieces/m3            10           Very High  stainless-steel sampler
# 178  pieces/m3            10           Very High  stainless-steel sampler
# 179  pieces/m3            10           Very High  stainless-steel sampler
# 180  pieces/m3            10           Very High  stainless-steel sampler
# 181  pieces/m3            10           Very High  stainless-steel sampler
#
#         Short Reference                                     Long Reference  \
# 0    Barrows et al.2018  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 1    Barrows et al.2018  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 2    Barrows et al.2018  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 3    Barrows et al.2018  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 4    Barrows et al.2018  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# ..                  ...                                                ...
# 177     Zhu et al. 2019  Zhu, J., Q. Zhang, Y. Li, S. Tan, Z. Kang, X. ...
# 178     Zhu et al. 2019  Zhu, J., Q. Zhang, Y. Li, S. Tan, Z. Kang, X. ...
# 179     Zhu et al. 2019  Zhu, J., Q. Zhang, Y. Li, S. Tan, Z. Kang, X. ...
# 180     Zhu et al. 2019  Zhu, J., Q. Zhang, Y. Li, S. Tan, Z. Kang, X. ...
# 181     Zhu et al. 2019  Zhu, J., Q. Zhang, Y. Li, S. Tan, Z. Kang, X. ...
#
#                                                  DOI  \
# 0       https://doi.org/10.1016/j.envpol.2018.02.062
# 1       https://doi.org/10.1016/j.envpol.2018.02.062
# 2       https://doi.org/10.1016/j.envpol.2018.02.062
# 3       https://doi.org/10.1016/j.envpol.2018.02.062
# 4       https://doi.org/10.1016/j.envpol.2018.02.062
# ..                                               ...
# 177  https://doi.org/10.1016/j.scitotenv.2018.12.192
# 178  https://doi.org/10.1016/j.scitotenv.2018.12.192
# 179  https://doi.org/10.1016/j.scitotenv.2018.12.192
# 180  https://doi.org/10.1016/j.scitotenv.2018.12.192
# 181  https://doi.org/10.1016/j.scitotenv.2018.12.192
#
#                      Organization  NCEI Accession Number  \
# 0             Adventure Scientist                 211009
# 1             Adventure Scientist                 211009
# 2             Adventure Scientist                 211009
# 3             Adventure Scientist                 211009
# 4             Adventure Scientist                 211009
# ..                            ...                    ...
# 177  Beibu Gulf University, China                 280675
# 178  Beibu Gulf University, China                 280675
# 179  Beibu Gulf University, China                 280675
# 180  Beibu Gulf University, China                 280675
# 181  Beibu Gulf University, China                 280675
#
#                                    NCEI Accession Link  Density Center
# 0    https://www.ncei.noaa.gov/access/metadata/land...         0.00275
# 1    https://www.ncei.noaa.gov/access/metadata/land...         0.00025
# 2    https://www.ncei.noaa.gov/access/metadata/land...         0.50250
# 3    https://www.ncei.noaa.gov/access/metadata/land...         0.00025
# 4    https://www.ncei.noaa.gov/access/metadata/land...         0.00025
# ..                                                 ...             ...
# 177  https://www.ncei.noaa.gov/access/metadata/land...        10.00000
# 178  https://www.ncei.noaa.gov/access/metadata/land...        10.00000
# 179  https://www.ncei.noaa.gov/access/metadata/land...        10.00000
# 180  https://www.ncei.noaa.gov/access/metadata/land...        10.00000
# 181  https://www.ncei.noaa.gov/access/metadata/land...        10.00000
#
# [182 rows x 19 columns]

# %%
df_chi.to_csv('files\clean_files(galapa, china, granreef)/South_China_Sea1.csv', index=False)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\isaw9\AppData\Local\Temp\ipykernel_20880\483913843.py:1: SyntaxWarning: invalid escape sequence '\c'
#   df_chi.to_csv('files\clean_files(galapa, china, granreef)/South_China_Sea1.csv', index=False)
