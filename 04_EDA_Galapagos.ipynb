# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import pandas as pd
import numpy as np

# Imputación de nulos usando métodos avanzados estadísticos
# -----------------------------------------------------------------------
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# Configuración
# -----------------------------------------------------------------------
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames

# %%
df_gal = pd.read_csv(
    "Proyecto-PowerBI-MOD4/files/Marine Microplastic Concentrations_GALAPAGOS.csv",
    sep=";",
    engine="python",
    encoding="utf-8",
    quotechar='"',
    on_bad_lines='warn'  # también puedes usar 'skip' para ignorar líneas malas
)

df_gal.head()
# Out:
#    OBJECTID        Date  Latitude  Longitude         Oceans    Regions  \
# 0      6191  04/12/2001      0.07     -897.9  Pacific Ocean  Galápagos
# 1      6192  05/12/2001     -0.51     -900.8  Pacific Ocean  Galápagos
# 2      6193  08/12/2001     -0.87     -902.6  Pacific Ocean  Galápagos
# 3      6194  09/12/2001    -12.10     -904.3  Pacific Ocean  Galápagos
# 4      6195  09/12/2001    -10.70     -908.4  Pacific Ocean  Galápagos
#
#     Location  Microplastics Measurement (density)       Unit  \
# 0  Galápagos                                  0.0  pieces/m3
# 1  Galápagos                                  0.0  pieces/m3
# 2  Galápagos                                  0.0  pieces/m3
# 3  Galápagos                                  0.0  pieces/m3
# 4  Galápagos                                  0.0  pieces/m3
#
#   Density Class Range Concentration Class Sampling Method Short Reference  \
# 0            0-0.0005            Very Low     Neuston net  Law et al.2014
# 1            0-0.0005            Very Low     Neuston net  Law et al.2014
# 2            0-0.0005            Very Low     Neuston net  Law et al.2014
# 3            0-0.0005            Very Low     Neuston net  Law et al.2014
# 4            0-0.0005            Very Low     Neuston net  Law et al.2014
#
#                                       Long Reference  \
# 0  Law, K.L, S.K. Morét-Ferguson, D.S. Goodwin, E...
# 1  Law, K.L, S.K. Morét-Ferguson, D.S. Goodwin, E...
# 2  Law, K.L, S.K. Morét-Ferguson, D.S. Goodwin, E...
# 3  Law, K.L, S.K. Morét-Ferguson, D.S. Goodwin, E...
# 4  Law, K.L, S.K. Morét-Ferguson, D.S. Goodwin, E...
#
#                                  DOI               Organization Keywords  \
# 0  https://doi.org/10.1021/es4053076  Sea Education Association      SEA
# 1  https://doi.org/10.1021/es4053076  Sea Education Association      SEA
# 2  https://doi.org/10.1021/es4053076  Sea Education Association      SEA
# 3  https://doi.org/10.1021/es4053076  Sea Education Association      SEA
# 4  https://doi.org/10.1021/es4053076  Sea Education Association      SEA
#
#    NCEI Accession Number                                NCEI Accession Link
# 0                 211008  https://www.ncei.noaa.gov/access/metadata/land...
# 1                 211008  https://www.ncei.noaa.gov/access/metadata/land...
# 2                 211008  https://www.ncei.noaa.gov/access/metadata/land...
# 3                 211008  https://www.ncei.noaa.gov/access/metadata/land...
# 4                 211008  https://www.ncei.noaa.gov/access/metadata/land...

# %%
# Función para conocer nulos y duplicados en un informe. Next step--> ETL

def nulos_duplicados(df_gal):
    # Cálculo del porcentaje de nulos
    porcentaje_nulos = df_gal.isna().sum() / df_gal.shape[0] * 100
    
    # Verificación de duplicados
    duplicados = df_gal.duplicated().sum()
    if duplicados == 0:
        mensaje_duplicados = "No hay duplicados"
    else:
        mensaje_duplicados = f"Hay {duplicados} duplicados"
    
    # Creación de un reporte bonito y visual
    reporte = f"""
    ===================== Informe de Datos =====================
    
    Porcentaje de Nulos por Columna:
    ------------------------------------------------------------
    {porcentaje_nulos.to_string()}
    
    ------------------------------------------------------------
    Duplicados:
    ------------------------------------------------------------
    {mensaje_duplicados}
    
    ============================================================
    """
    
    # Imprimir directamente el reporte
    print(reporte)

# Ejemplo de uso
# df_mp = pd.DataFrame(...)

# Llamar directamente a la función
nulos_duplicados(df_gal)
# Out:
#     ===================== Informe de Datos =====================
#
#     Porcentaje de Nulos por Columna:
#     ------------------------------------------------------------
#     OBJECTID                               0.0
# Date                                   0.0
# Latitude                               0.0
# Longitude                              0.0
# Oceans                                 0.0
# Regions                                0.0
# Location                               0.0
# Microplastics Measurement (density)    0.0
# Unit                                   0.0
# Density Class Range                    0.0
# Concentration Class                    0.0
# Sampling Method                        0.0
# Short Reference                        0.0
# Long Reference                         0.0
# DOI                                    0.0
# Organization                           0.0
# Keywords                               0.0
# NCEI Accession Number                  0.0
# NCEI Accession Link                    0.0
#
#     ------------------------------------------------------------
#     Duplicados:
#     ------------------------------------------------------------
#     No hay duplicados
#
#     ============================================================

# %%
# Columna de media de density

# Función para eliminar el símbolo '>= y >'
def eliminar_menor_igual(rango):
    return rango.replace('>=','').replace('>','').strip()

# Aplicamos la función para eliminar '>=' de la columna 'Density Range'
df_gal['Density Class Range'] = df_gal['Density Class Range'].apply(eliminar_menor_igual)

# %%
# Función para extraer los valores numéricos y calcular el valor central
def calcular_densidad_central(rango):
    # Si el valor es solo un número
    if '-' not in rango:  # Caso cuando no hay guion, es un solo número
        return float(rango.strip())
    
    # Si el valor es un rango (con '-')
    else:
        # Extraemos los valores del rango y calculamos el promedio
        min_val, max_val = map(float, rango.replace(' ', '').split('-'))  # Convertimos los valores en float
        return (min_val + max_val) / 2  # Calculamos el promedio del rango

# Aplicamos la función a la columna 'Density Range' y creamos la nueva columna 'Density_Center'
df_gal['Density Center'] = df_gal['Density Class Range'].apply(calcular_densidad_central)

# %%
df_gal
# Out:
#     OBJECTID        Date  Latitude  Longitude         Oceans    Regions  \
# 0       6191  04/12/2001    0.0700   -897.900  Pacific Ocean  Galápagos
# 1       6192  05/12/2001   -0.5100   -900.800  Pacific Ocean  Galápagos
# 2       6193  08/12/2001   -0.8700   -902.600  Pacific Ocean  Galápagos
# 3       6194  09/12/2001  -12.1000   -904.300  Pacific Ocean  Galápagos
# 4       6195  09/12/2001  -10.7000   -908.400  Pacific Ocean  Galápagos
# 5       6196  10/12/2001  -11.3000   -919.600  Pacific Ocean  Galápagos
# 6       8982  24/11/2014   -0.7485   -903.131  Pacific Ocean  Galápagos
# 7       9371  06/02/2015    0.2891   -905.589  Pacific Ocean  Galápagos
# 8       9373  07/02/2015    0.3140   -899.471  Pacific Ocean  Galápagos
# 9       9806  25/04/2016   -0.5700   -905.700  Pacific Ocean  Galápagos
# 10      9828  30/06/2016   -0.8980   -896.147  Pacific Ocean  Galápagos
# 11     12184  11/10/2017  -15.0000   -890.000  Pacific Ocean  Galápagos
# 12     12185  11/10/2017  -10.0000   -890.000  Pacific Ocean  Galápagos
# 13     12186  12/10/2017   -0.9000   -902.500  Pacific Ocean  Galápagos
# 14     12187  15/10/2017   -0.7100   -906.500  Pacific Ocean  Galápagos
# 15     12188  16/10/2017  -13.0000   -910.000  Pacific Ocean  Galápagos
# 16     12190  18/10/2017  -15.0000   -920.000  Pacific Ocean  Galápagos
# 17     12191  18/10/2017  -10.0000   -920.000  Pacific Ocean  Galápagos
# 18     12192  19/10/2017   -0.5000   -920.000  Pacific Ocean  Galápagos
# 19     12193  19/10/2017    0.0000   -920.000  Pacific Ocean  Galápagos
# 20     12201  25/10/2017    0.0000   -890.000  Pacific Ocean  Galápagos
# 21     12202  26/10/2017   -0.5000   -890.000  Pacific Ocean  Galápagos
#
#      Location  Microplastics Measurement (density)       Unit  \
# 0   Galápagos                                0.000  pieces/m3
# 1   Galápagos                                0.000  pieces/m3
# 2   Galápagos                                0.000  pieces/m3
# 3   Galápagos                                0.000  pieces/m3
# 4   Galápagos                                0.000  pieces/m3
# 5   Galápagos                                0.000  pieces/m3
# 6   Galápagos                                0.001  pieces/m3
# 7   Galápagos                                0.003  pieces/m3
# 8   Galápagos                                0.002  pieces/m3
# 9   Galápagos                                0.003  pieces/m3
# 10  Galápagos                                0.001  pieces/m3
# 11  Galápagos                                0.780  pieces/m3
# 12  Galápagos                                0.420  pieces/m3
# 13  Galápagos                                0.190  pieces/m3
# 14  Galápagos                                0.470  pieces/m3
# 15  Galápagos                                0.420  pieces/m3
# 16  Galápagos                                0.420  pieces/m3
# 17  Galápagos                                0.540  pieces/m3
# 18  Galápagos                                0.490  pieces/m3
# 19  Galápagos                                0.220  pieces/m3
# 20  Galápagos                                0.470  pieces/m3
# 21  Galápagos                                0.510  pieces/m3
#
#    Density Class Range Concentration Class Sampling Method  \
# 0             0-0.0005            Very Low     Neuston net
# 1             0-0.0005            Very Low     Neuston net
# 2             0-0.0005            Very Low     Neuston net
# 3             0-0.0005            Very Low     Neuston net
# 4             0-0.0005            Very Low     Neuston net
# 5             0-0.0005            Very Low     Neuston net
# 6         0.0005-0.005                 Low     Grab sample
# 7         0.0005-0.005                 Low     Grab sample
# 8         0.0005-0.005                 Low     Grab sample
# 9         0.0005-0.005                 Low     Grab sample
# 10        0.0005-0.005                 Low     Grab sample
# 11             0.005-1              Medium    Plankton net
# 12             0.005-1              Medium    Plankton net
# 13             0.005-1              Medium    Plankton net
# 14             0.005-1              Medium    Plankton net
# 15             0.005-1              Medium    Plankton net
# 16             0.005-1              Medium    Plankton net
# 17             0.005-1              Medium    Plankton net
# 18             0.005-1              Medium    Plankton net
# 19             0.005-1              Medium    Plankton net
# 20             0.005-1              Medium    Plankton net
# 21             0.005-1              Medium    Plankton net
#
#             Short Reference  \
# 0            Law et al.2014
# 1            Law et al.2014
# 2            Law et al.2014
# 3            Law et al.2014
# 4            Law et al.2014
# 5            Law et al.2014
# 6        Barrows et al.2018
# 7        Barrows et al.2018
# 8        Barrows et al.2018
# 9        Barrows et al.2018
# 10       Barrows et al.2018
# 11  Alfaro-Núñez et al.2021
# 12  Alfaro-Núñez et al.2021
# 13  Alfaro-Núñez et al.2021
# 14  Alfaro-Núñez et al.2021
# 15  Alfaro-Núñez et al.2021
# 16  Alfaro-Núñez et al.2021
# 17  Alfaro-Núñez et al.2021
# 18  Alfaro-Núñez et al.2021
# 19  Alfaro-Núñez et al.2021
# 20  Alfaro-Núñez et al.2021
# 21  Alfaro-Núñez et al.2021
#
#                                        Long Reference  \
# 0   Law, K.L, S.K. Morét-Ferguson, D.S. Goodwin, E...
# 1   Law, K.L, S.K. Morét-Ferguson, D.S. Goodwin, E...
# 2   Law, K.L, S.K. Morét-Ferguson, D.S. Goodwin, E...
# 3   Law, K.L, S.K. Morét-Ferguson, D.S. Goodwin, E...
# 4   Law, K.L, S.K. Morét-Ferguson, D.S. Goodwin, E...
# 5   Law, K.L, S.K. Morét-Ferguson, D.S. Goodwin, E...
# 6   Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 7   Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 8   Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 9   Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 10  Barrows, A.P.W., S.E. Cathey, C.W. Petersen. 2...
# 11  Alfaro-Núñez, A., D. Astorga, L. Cáceres-Faría...
# 12  Alfaro-Núñez, A., D. Astorga, L. Cáceres-Faría...
# 13  Alfaro-Núñez, A., D. Astorga, L. Cáceres-Faría...
# 14  Alfaro-Núñez, A., D. Astorga, L. Cáceres-Faría...
# 15  Alfaro-Núñez, A., D. Astorga, L. Cáceres-Faría...
# 16  Alfaro-Núñez, A., D. Astorga, L. Cáceres-Faría...
# 17  Alfaro-Núñez, A., D. Astorga, L. Cáceres-Faría...
# 18  Alfaro-Núñez, A., D. Astorga, L. Cáceres-Faría...
# 19  Alfaro-Núñez, A., D. Astorga, L. Cáceres-Faría...
# 20  Alfaro-Núñez, A., D. Astorga, L. Cáceres-Faría...
# 21  Alfaro-Núñez, A., D. Astorga, L. Cáceres-Faría...
#
#                                              DOI  \
# 0              https://doi.org/10.1021/es4053076
# 1              https://doi.org/10.1021/es4053076
# 2              https://doi.org/10.1021/es4053076
# 3              https://doi.org/10.1021/es4053076
# 4              https://doi.org/10.1021/es4053076
# 5              https://doi.org/10.1021/es4053076
# 6   https://doi.org/10.1016/j.envpol.2018.02.062
# 7   https://doi.org/10.1016/j.envpol.2018.02.062
# 8   https://doi.org/10.1016/j.envpol.2018.02.062
# 9   https://doi.org/10.1016/j.envpol.2018.02.062
# 10  https://doi.org/10.1016/j.envpol.2018.02.062
# 11    https://doi.org/10.1038/s41598-021-85939-3
# 12    https://doi.org/10.1038/s41598-021-85939-3
# 13    https://doi.org/10.1038/s41598-021-85939-3
# 14    https://doi.org/10.1038/s41598-021-85939-3
# 15    https://doi.org/10.1038/s41598-021-85939-3
# 16    https://doi.org/10.1038/s41598-021-85939-3
# 17    https://doi.org/10.1038/s41598-021-85939-3
# 18    https://doi.org/10.1038/s41598-021-85939-3
# 19    https://doi.org/10.1038/s41598-021-85939-3
# 20    https://doi.org/10.1038/s41598-021-85939-3
# 21    https://doi.org/10.1038/s41598-021-85939-3
#
#                          Organization                             Keywords  \
# 0           Sea Education Association                                  SEA
# 1           Sea Education Association                                  SEA
# 2           Sea Education Association                                  SEA
# 3           Sea Education Association                                  SEA
# 4           Sea Education Association                                  SEA
# 5           Sea Education Association                                  SEA
# 6                 Adventure Scientist  Adventure Scientist/Citizen Science
# 7                 Adventure Scientist  Adventure Scientist/Citizen Science
# 8                 Adventure Scientist  Adventure Scientist/Citizen Science
# 9                 Adventure Scientist  Adventure Scientist/Citizen Science
# 10                Adventure Scientist  Adventure Scientist/Citizen Science
# 11  University of Copenhagen, Denmark                             RV Orion
# 12  University of Copenhagen, Denmark                             RV Orion
# 13  University of Copenhagen, Denmark                             RV Orion
# 14  University of Copenhagen, Denmark                             RV Orion
# 15  University of Copenhagen, Denmark                             RV Orion
# 16  University of Copenhagen, Denmark                             RV Orion
# 17  University of Copenhagen, Denmark                             RV Orion
# 18  University of Copenhagen, Denmark                             RV Orion
# 19  University of Copenhagen, Denmark                             RV Orion
# 20  University of Copenhagen, Denmark                             RV Orion
# 21  University of Copenhagen, Denmark                             RV Orion
#
#     NCEI Accession Number                                NCEI Accession Link  \
# 0                  211008  https://www.ncei.noaa.gov/access/metadata/land...
# 1                  211008  https://www.ncei.noaa.gov/access/metadata/land...
# 2                  211008  https://www.ncei.noaa.gov/access/metadata/land...
# 3                  211008  https://www.ncei.noaa.gov/access/metadata/land...
# 4                  211008  https://www.ncei.noaa.gov/access/metadata/land...
# 5                  211008  https://www.ncei.noaa.gov/access/metadata/land...
# 6                  211009  https://www.ncei.noaa.gov/access/metadata/land...
# 7                  211009  https://www.ncei.noaa.gov/access/metadata/land...
# 8                  211009  https://www.ncei.noaa.gov/access/metadata/land...
# 9                  211009  https://www.ncei.noaa.gov/access/metadata/land...
# 10                 211009  https://www.ncei.noaa.gov/access/metadata/land...
# 11                 276018  https://www.ncei.noaa.gov/access/metadata/land...
# 12                 276018  https://www.ncei.noaa.gov/access/metadata/land...
# 13                 276018  https://www.ncei.noaa.gov/access/metadata/land...
# 14                 276018  https://www.ncei.noaa.gov/access/metadata/land...
# 15                 276018  https://www.ncei.noaa.gov/access/metadata/land...
# 16                 276018  https://www.ncei.noaa.gov/access/metadata/land...
# 17                 276018  https://www.ncei.noaa.gov/access/metadata/land...
# 18                 276018  https://www.ncei.noaa.gov/access/metadata/land...
# 19                 276018  https://www.ncei.noaa.gov/access/metadata/land...
# 20                 276018  https://www.ncei.noaa.gov/access/metadata/land...
# 21                 276018  https://www.ncei.noaa.gov/access/metadata/land...
#
#     Density Center
# 0          0.00025
# 1          0.00025
# 2          0.00025
# 3          0.00025
# 4          0.00025
# 5          0.00025
# 6          0.00275
# 7          0.00275
# 8          0.00275
# 9          0.00275
# 10         0.00275
# 11         0.50250
# 12         0.50250
# 13         0.50250
# 14         0.50250
# 15         0.50250
# 16         0.50250
# 17         0.50250
# 18         0.50250
# 19         0.50250
# 20         0.50250
# 21         0.50250

# %%
#Guardar csv limpio
df_gal.to_csv('Galapagos.csv', index=False)
